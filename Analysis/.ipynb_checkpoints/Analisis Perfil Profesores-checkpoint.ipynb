# %% [markdown]
# # Análisis de la vida académica de la Facultad de Ciencias
# ## Perfil de Profesores

# %% [markdown]
# ### Carga de librerías para el análisis

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargar bases de datos que utilizaremos

# %%
df_courses=pd.read_csv('../Data/courses.csv', dtype = {'ID': str,'CourseName': str}).set_index('ID')

df_groups=pd.read_csv('../Data/groups.csv', dtype = {'GroupYSID': str,'Quota': int,'Signed':int}).set_index('GroupYSID')

df_profs=pd.read_csv('../Data/profs-all.csv', dtype = {'ID': int, 'Name':str, 'Appointment':str,'SimpAppointment': 'category'}).set_index('ID')

df_teaching=pd.read_csv('../Data/teaching.csv', dtype = {'ProfID': int,'GroupYSID': str,'ProfType':'category', 'Days': str, 'Hours': str})

df_plans=pd.read_csv('../Data/plans_courses.csv', dtype={'CourseID':int,'PlanID':"int64",'CourseType':'category'})

df_plan_names=pd.read_csv('../Data/plans.csv').set_index('ID')

# Hay algunas materias homólogas que no queremos que estén
df_homologas=pd.read_csv('../Data/homologas.csv')
df_homologas['old_name_code']=df_homologas['old_name_code'].apply(lambda x: '{:0>4d}'.format(x))
df_homologas['new_name_code']=df_homologas['new_name_code'].apply(lambda x: '{:0>4d}'.format(x))

# %%
for df in [df_courses, df_groups, df_profs, df_teaching, df_plans]:
    display(df.sample(3))
# Out:
#                                              CourseName
# ID
# 1432  Elaboración y Desarrollo de Proyectos Experime...
# 0417                                    Ecología Marina
# 1218                                   Química Orgánica
#                   Quota  Signed
# GroupYSID
# 2017-2-0277-4314     35      13
# 2001-2-0988-4198      6       6
# 2011-1-0339-7006      0      22
#                                                Name                     Mail  \
# ID
# 55496  L. en C.C. Mitzi Zoraida De la Cruz Pimentel               Escribenos
# 33206          Lic. Marco Antonio Esquivel Pichardo               Escribenos
# 59609                    Fís. Cesar Cossio Guerrero  footbagxero@hotmail.com
#
#                                Appointment SimpAppointment
# ID
# 55496  Ayudante de Profesora de Asignatura            Ayud
# 33206               Profesor de Asignatura              PA
# 59609   Ayudante de Profesor de Asignatura            Ayud
#         ProfID         GroupYSID  ProfType   Days    Hours
# 15535    31014  2007-1-1103-5073  Ayudante     mi  14 a 16
# 145628   95527  2021-2-1800-5440  Profesor    NaN      NaN
# 8568     25191  2005-2-0601-1024  Ayudante  ma ju    7 a 8
#       CourseID  PlanID   CourseType
# 1118      1092     201     Optativa
# 824        652     134     Optativa
# 890        919     136  Obligatoria

# %% [markdown]
# ### Agregar funciones útiles

# %%
def get_course_name(courseid):
    try:
        if type(courseid)==int:
            courseid='{:0>4d}'.format(courseid)
        if type(courseid)==str:
            return(df_courses.loc[courseid]['CourseName'])
    except:
        return "Not found"
    
def es_asignatura(text):
    if text=='PA':
        return(1)
    else:
        return(0)

# %% [markdown]
# ### Agregar columnas útiles

# %% [markdown]
# Para `df_teaching`

# %%
df_teaching['CourseID']=df_teaching['GroupYSID'].apply(lambda x: x.split('-')[-2])
df_teaching['Semester']=df_teaching['GroupYSID'].apply(lambda x:x[:6])
df_teaching['CourseName']=df_teaching['CourseID'].apply(get_course_name)
display(df_teaching['CourseID'].head())
display(df_teaching['Semester'].head())
display(df_teaching['CourseName'].head())
# Out:
# 0    2017
# 1    0307
# 2    0827
# 3    0302
# 4    0302
# Name: CourseID, dtype: object
# 0    2016-1
# 1    2006-2
# 2    2008-1
# 3    2007-1
# 4    2007-2
# Name: Semester, dtype: object
# 0                          Meteorología
# 1    Máquinas Digitales con Laboratorio
# 2        Dinámica de Medios Deformables
# 3                  Fenómenos Colectivos
# 4                  Fenómenos Colectivos
# Name: CourseName, dtype: object

# %% [markdown]
# Para `df_profs`

# %%
df_profs['Asignatura']=df_profs['SimpAppointment'].apply(es_asignatura)

# %% [markdown]
# ### Tipos de semestre

# %%
sem_1=['{}-1'.format(j) for j in range(2001,2022)]
sem_2=['{}-2'.format(j) for j in range(2001,2022)]
sem_3=['{}-3'.format(j) for j in range(2001,2022)]
sem_4=['{}-4'.format(j) for j in range(2001,2022)]
sem_regular=sorted(sem_1+sem_2)
sem_inter=sorted(sem_3+sem_4)
sem_1_recent=['{}-1'.format(j) for j in range(2017,2022)]
sem_2_recent=['{}-2'.format(j) for j in range(2017,2022)]
sem_3_recent=['{}-3'.format(j) for j in range(2017,2022)]
sem_4_recent=['{}-4'.format(j) for j in range(2017,2022)]
sem_regular_recent=sorted(sem_1_recent+sem_2_recent)
sem_inter_recent=sorted(sem_3_recent+sem_3_recent)

# %% [markdown]
# ## Join de la información

# %%
df_teaching_join=df_teaching.join(df_groups,on='GroupYSID').join(df_profs, on='ProfID')
df_teaching_join['Asignatura']=df_teaching_join['SimpAppointment'].apply(es_asignatura)
df_teaching_join.head()

# Quitamos las materias homólogas. Dejamos sólo con el nombre reciente.
print(df_teaching_join.shape)
df_teaching_join=df_teaching_join[~df_teaching_join['CourseID'].isin(df_homologas['old_name_code'])]
print(df_teaching_join.shape)
# Out:
# (146660, 15)
# (140357, 15)

# %%
df_teaching_join.sample(5)
# Out:
#        ProfID         GroupYSID  ProfType      Days         Hours CourseID  \
# 40454   33678  2010-2-1403-5166  Profesor        ju     8:30 a 10     1403
# 77032   45224  2019-2-1201-5323  Profesor        mi  7:30 a 10:30     1201
# 88076   52968  2008-2-1409-6036  Ayudante     ma ju         8 a 9     1409
# 80434   45770  2013-1-1700-5486  Profesor       NaN           NaN     1700
# 41933   33742  2004-2-0091-4012  Ayudante  ma ju vi       11 a 12     0091
#
#       Semester                         CourseName  Quota  Signed  \
# 40454   2010-2             Biología de Plantas II     25      25
# 77032   2019-2  Biología Molecular de la Célula I     25      24
# 88076   2008-2                         Finanzas I      0      96
# 80434   2013-1                     Taller Nivel 3      0       6
# 41933   2004-2   Cálculo Diferencial e Integral I      0      60
#
#                                          Name                     Mail  \
# 40454     Dra. Martha Juana Martínez Gordillo    mjmg@ciencias.unam.mx
# 77032   Dra. Bertha Verónica Valverde Garduño  verovg@ciencias.unam.mx
# 88076        Act. Miguel Angel Morales Naveda      mike.juez@gmail.com
# 80434  Dra. Teresa Imelda Fortoul Vander Goes          fortoul@unam.mx
# 41933            María Berenice Mendoza Gamez               Escribenos
#
#                                Appointment SimpAppointment  Asignatura
# 40454            Técnica Académica Titular             Tec         0.0
# 77032              Profesora de Asignatura              PA         1.0
# 88076   Ayudante de Profesor de Asignatura            Ayud         0.0
# 80434         Profesora de Carrera Titular             PTC         0.0
# 41933  Ayudante de Profesora de Asignatura            Ayud         0.0

# %% [markdown]
# ## Profesores actuales del departamento de matemáticas

# %%
df_matematicas=df_plans[df_plans.PlanID==122].CourseID.apply(lambda x: '{:0>4d}'.format(x))
df_matematicas
# Out:
# 466    0007
# 467    0091
# 468    0244
# 469    0249
# 470    0008
#        ...
# 738    0032
# 739    0034
# 740    0053
# 741    0686
# 742    0580
# Name: CourseID, Length: 277, dtype: object

# %%
filtro_1=df_teaching_join['Semester']=='2021-2'
filtro_2=df_teaching_join['CourseID'].isin(df_matematicas)
filtro_3=df_teaching_join['ProfType']=='Profesor'

# %%
df_aux=df_teaching_join[filtro_1&filtro_2&filtro_3][['ProfID','CourseName','Name','CourseID','Quota','Signed','Appointment','SimpAppointment','Asignatura']]
df_aux
# Out:
#         ProfID                             CourseName  \
# 42        1987      Cálculo Diferencial e Integral II
# 106       2138      Seminario Matemáticas Aplicadas I
# 439       4102       Cálculo Diferencial e Integral I
# 754       4944                     Álgebra Superior I
# 968       5478                   Fenómenos Colectivos
# ...        ...                                    ...
# 146423  101173                    Álgebra Superior II
# 146588  101508                     Conjuntos y Lógica
# 146633  103773           México: Nación Multicultural
# 146652  103809               Seminario de Topología A
# 146658  103835  Introducción a los Sistemas Complejos
#
#                                                  Name CourseID  Quota  Signed  \
# 42               Lic. Alberto Manuel Aldama Garisoain     0092     65      33
# 106                Dr. Pedro Eduardo Miramontes Vidal     0735     65      15
# 439                                  Mat. José Santos     0091     65      10
# 754                      M. en C. Jorge Ortiz Espejel     0007     65      10
# 968                   Dra. Patricia Goldstein Menache     0302     60      60
# ...                                               ...      ...    ...     ...
# 146423  Mtra. en Matemáticas Arilín Susana Haro Palma     0008    137     137
# 146588                  M. en C. Sonia Navarro Flores     0271     65      12
# 146633                      María Teresa Romero Tovar     0291     60      50
# 146652                    Dr. Carlos Segovia González     0977     65       1
# 146658                   Dr. Maximino Aldana González     1048      0      70
#
#                          Appointment SimpAppointment  Asignatura
# 42            Profesor de Asignatura              PA         1.0
# 106      Profesor de Carrera Titular             PTC         0.0
# 439           Profesor de Asignatura              PA         1.0
# 754           Profesor de Asignatura              PA         1.0
# 968     Profesora de Carrera Titular             PTC         0.0
# ...                              ...             ...         ...
# 146423       Profesora de Asignatura              PA         1.0
# 146588       Profesora de Asignatura              PA         1.0
# 146633       Profesora de Asignatura              PA         1.0
# 146652        Profesor de Asignatura              PA         1.0
# 146658        Profesor de Asignatura              PA         1.0
#
# [559 rows x 9 columns]

# %%
df_aux2=df_aux.groupby(['ProfID']).agg({'CourseID':'count','Signed':'sum','Name':'first','Appointment':'first'}).sort_values(by='Signed',ascending=False)
df_aux2.head(20)
# Out:
#         CourseID  Signed                                           Name  \
# ProfID
# 60028          3     383         Dr. Leonardo Ignacio Martínez Sandoval
# 53980          3     356             Dra. María del Rocío Sánchez López
# 34616          1     260                   Act. Javier Fernández García
# 65901          1     215          Mat. Francisco Giovanni López Sánchez
# 59231          2     202                   M. en D. Adriana León Montes
# 33726          2     176                        Dra. Ana Meda Guardiola
# 72234          1     168          M. en C. Omar Patricio Juárez Álvarez
# 58811          1     166                  Dr. Alejandro Dorantes Aldama
# 63853          2     160          Dra. Natalia Bárbara Mantilla Beniers
# 33898          1     159                     Dra. Laura Ortiz Bobadilla
# 53967          2     156                Dr. Jorge Alonso Santos Mellado
# 18811          1     148                   Mat. Mario Delgadillo Torres
# 48506          2     146            Dr. Jorge Marcos Martínez Montejano
# 34267          2     140      M. en C. Elhoim Llorente Sumano y Ramírez
# 28731          2     140                 Dr. Erick Javier López Sánchez
# 101173         1     137  Mtra. en Matemáticas Arilín Susana Haro Palma
# 27062          2     137                   Mat. José Juan Ley Mandujano
# 52552          2     135                     Dra. Judith Campos Cordero
# 52564          2     133              Dr. Juan Carlos Fernández Morelos
# 62573          2     130             M. en C. Mindy Yaneli Huerta Pérez
#
#                              Appointment
# ProfID
# 60028       Profesor de Carrera Asociado
# 53980      Profesora de Carrera Asociado
# 34616       Profesor de Carrera Asociado
# 65901             Profesor de Asignatura
# 59231            Profesora de Asignatura
# 33726       Profesora de Carrera Titular
# 72234             Profesor de Asignatura
# 58811             Profesor de Asignatura
# 63853       Profesora de Carrera Titular
# 33898   Investigadora de Carrera Titular
# 53967             Profesor de Asignatura
# 18811             Profesor de Asignatura
# 48506        Profesor de Carrera Titular
# 34267             Profesor de Asignatura
# 28731             Profesor de Asignatura
# 101173           Profesora de Asignatura
# 27062             Profesor de Asignatura
# 52552      Profesora de Carrera Asociado
# 52564             Profesor de Asignatura
# 62573            Profesora de Asignatura

# %%
df_aux2=df_aux[df_aux['Signed']>=100].sort_values(by='Signed',ascending=False)
df_aux2
# Out:
#         ProfID                          CourseName  \
# 61340    34616   Cálculo Diferencial e Integral II
# 121297   65901   Cálculo Diferencial e Integral IV
# 91413    53980                 Álgebra Superior II
# 128755   72234    Cálculo Diferencial e Integral I
# 104394   58811               Análisis Matemático I
# 45811    33898          Ecuaciones Diferenciales I
# 41690    33726                     Probabilidad II
# 4555     18811  Cálculo Diferencial e Integral III
# 146423  101173                 Álgebra Superior II
# 108448   60028                 Álgebra Superior II
# 108439   60028               Geometría Analítica I
# 108445   60028                   Álgebra Lineal II
# 86603    48506   Cálculo Diferencial e Integral II
# 117383   63853   Cálculo Diferencial e Integral II
# 107701   59769          Ecuaciones Diferenciales I
# 34604    33438              Geometría Analítica II
# 121271   65893          Ecuaciones Diferenciales I
# 44353    33840              Geometría Analítica II
# 106483   59231                 Álgebra Superior II
# 25130                Profesor de Asignatura              PA         1.0
# 10332                Profesor de Asignatura              PA         1.0
# 87909                Profesor de Asignatura              PA         1.0
# 124807               Profesor de Asignatura              PA         1.0
# 106727  Ayudante de Profesora de Asignatura            Ayud         0.0
# 77925               Profesora de Asignatura              PA         1.0
# 70179                Profesor de Asignatura              PA         1.0

# %% [markdown]
# ## Barchart race

# %%
import bar_chart_race as bcr

# %%
df_matematicas=df_plans[df_plans.PlanID==122].CourseID.apply(lambda x: '{:0>4d}'.format(x))
df_matematicas
filtro_1=df_teaching_join['Semester'].isin(sem_regular)
filtro_2=df_teaching_join['CourseID'].isin(df_matematicas)
filtro_3=df_teaching_join['ProfType']=='Profesor'
df_aux=df_teaching_join[filtro_2&filtro_3][['ProfID','CourseName','Semester','Name','CourseID','Quota','Signed','Appointment','SimpAppointment','Asignatura']]
df_aux=df_aux.groupby(['Semester','Name']).agg({'Signed':'sum'}).unstack(1).fillna(0)
df_aux.iloc[:,0:-1] = df_aux.iloc[:,0:-1].cumsum()
df_aux.head(10)
# Out:
#                             Signed                          \
# Name      Alfredo Castañeda Olvera  Daniel Hernández Reyes
# Semester
# 2001-1                         0.0                     0.0
# 2001-2                         0.0                     0.0
# 2002-1                         0.0                     0.0
# 2002-2                         0.0                     0.0
# 2003-1                         0.0                     0.0
# 2003-2                         0.0                     0.0
# 2004-1                         0.0                     0.0
# 2004-2                         0.0                     0.0
# 2005-1                         0.0                     0.0
# 2005-2                         0.0                     0.0
#
#                                                              \
# Name      Daniela Hérnandez Salcido  Edmundo Avendaño Mejía
# Semester
# 2001-1                          0.0                     0.0
# 2001-2                          0.0                     0.0
# 2002-1                          0.0                     0.0
# 2002-2                          0.0                     0.0
# 2003-1                          0.0                     0.0
# 2003-2                          0.0                     0.0
# 2004-1                          0.0                     0.0
# 2004-2                          0.0                     0.0
# 2005-1                          0.0                     0.0
# 2005-2                          0.0                     0.0
#
#                                                                       \
# Name     Act. Abraham Ramírez Hernández Act. Alejandra Juárez Torres
# Semester
# 2001-1                              0.0                          0.0
# 2001-2                              0.0                          0.0
# 2002-1                              0.0                          0.0
# 2002-2                              0.0                          0.0
# 2003-1                              0.0                          0.0
# 2003-2                              0.0                          0.0
# 2004-1                              0.0                          0.0
# 2004-2                              0.0                          0.0
# 2005-1                              0.0                          0.0
# 2005-2                              0.0                          0.0
#
#                                                                          \
# Name     Act. Alejandro Felipe Zarate Pérez Act. Alejandro Nava Camacho
# Semester
# 2001-1                                  0.0                         0.0
# 2001-2                                  0.0                         0.0
# 2002-1                                  0.0                         0.0
# 2002-2                                  0.0                         0.0
# 2003-1                                  0.0                         0.0
# 2003-2                                  0.0                         0.0
# 2004-1                                  0.0                         0.0
# 2004-2                                  0.0                         0.0
# 2005-1                                  0.0                         0.0
# 2005-2                                  0.0                         0.0
#
#                                                               ...  \
# Name     Act. Aravid Torres Garduño Act. Arturo Roldán López  ...
# Semester                                                      ...
# 2001-1                          0.0                      0.0  ...
missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1423 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1424 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1425 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1427 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1429 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1430 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1431 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1432 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1434 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1437 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1438 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1441 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1443 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1445 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1446 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1449 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1450 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1451 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1454 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1455 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1477 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1482 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1483 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1484 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1485 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1515 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1518 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1519 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1525 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1526 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1530 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1534 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1535 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1537 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1538 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1539 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1541 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1547 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1550 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1551 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1554 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1558 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1559 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1560 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1561 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1562 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1565 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1566 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1568 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1595 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1596 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1597 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1598 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1599 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1622 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1624 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1625 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1627 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1630 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1650 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1651 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1653 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1654 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1655 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 1656 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 134 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 135 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 136 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 137 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 138 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 139 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 143 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 149 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 151 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 155 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 157 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 159 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 746 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 747 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 751 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 752 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 753 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 754 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 756 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 757 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 758 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 760 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 761 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 762 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 763 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 764 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 765 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 766 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 767 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 852 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 853 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 854 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 859 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 867 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 870 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 871 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 872 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 873 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 874 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 875 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 876 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 877 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 878 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 879 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 895 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 897 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 898 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1485 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1486 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1487 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1515 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1518 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1519 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1525 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1526 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1527 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1528 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1530 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1531 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1533 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1534 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1535 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1537 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1538 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1539 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1541 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1547 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1549 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1550 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1551 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1553 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1554 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1555 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1556 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1558 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1559 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1560 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1561 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1562 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1564 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1565 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1566 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1568 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1595 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1596 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1597 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1598 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1599 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1622 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1624 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1625 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1627 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1630 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1631 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1649 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1650 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1651 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1653 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1654 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1655 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 1656 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\pktgc\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\pktgc\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# C:\Users\pktgc\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:226: UserWarning: Some of your columns never make an appearance in the animation. To reduce color repetition, set `filter_column_colors` to `True`
#   warnings.warn("Some of your columns never make an appearance in the animation. "
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in grab_frame(self, **savefig_kwargs)
#     548             buf, **{**savefig_kwargs, "format": "rgba", "dpi": self.dpi})
# --> 549         renderer = self.fig.canvas.get_renderer()
#     550         self._frames.append(Image.frombuffer(
#
# AttributeError: 'FigureCanvasBase' object has no attribute 'get_renderer'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in make_animation(self)
#     434             else:
# --> 435                 ret_val = anim.save(self.filename, fps=self.fps, writer=self.writer)
#     436         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     252         finally:
# --> 253             self.finish()
#     254
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     553     def finish(self):
# --> 554         self._frames[0].save(
#     555             self.outfile, save_all=True, append_images=self._frames[1:],
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-33-c736a0405fdb> in <module>
# ----> 1 bcr.bar_chart_race(df = df_aux,
#       2                    n_bars = 6,
#       3                    sort='desc',
#       4                    title='Premier League Clubs Points Since 1992',
#       5                    filename = 'pl_clubs.mp4')
#
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in bar_chart_race(df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
#     781                         figsize, cmap, title, title_size, bar_label_size, tick_label_size,
#     782                         shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
# --> 783     return bcr.make_animation()
#     784
#     785 def load_dataset(name='covid19'):
#
# ~\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py in make_animation(self)
#     444             else:
#     445                 message = str(e)
# --> 446             raise Exception(message)
#     447         finally:
#     448             plt.rcParams = self.orig_rcParams
#
# Exception: You do not have ffmpeg installed on your machine. Download
#                             ffmpeg from here: https://www.ffmpeg.org/download.html.
#
#                             Matplotlib's original error message below:
#
#                             list index out of range
